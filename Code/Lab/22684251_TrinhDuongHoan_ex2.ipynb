# %% [markdown]
# # Lab 02 - Bài tập

# %% [markdown]
# ## NUMPY
#
# Bạn hãy phát sinh ngẫu nhiên mảng ndarray có tên `arr` gồm 100 phần tử số nguyên có giá trị từ 0..1000. Thực hiện các thao tác sau:

# %%
import numpy as np
arr = np.random.randint(0, 1000, 100)

# %% [markdown]
# ### 1. Hiển thị các phần tử thỏa yêu cầu dưới đây
#
# - 10 phần tử đầu tiên
# - 5 phần tử cuối cùng
# - Các phần tử thỏa mãn điều kiện chia hết cho 5 và lớn hơn 100

# %%
print(arr[:10])
# Out:
# [603 958  84 587 861 537 857  26 569 485]

# %%
print(arr[-5:])
# Out:
# [573 370 799 940 130]

# %%
for val in arr :
    if val % 5 == 0 and val > 100 :
        print(val, end = ' ')
# Out:
# 485 540 395 630 500 765 245 850 350 615 960 130 385 815 730 370 940 130

# %% [markdown]
# ### 2. Cho biết mảng trên có bao nhiêu phần tử có giá trị nhỏ hơn 100. Hiển thị các phần tử đó

# %%
less_than_100 = [int(val) for val in arr if val < 100]
print(len(less_than_100))
print(less_than_100)
# Out:
# 9
# [84, 26, 5, 94, 93, 81, 2, 43, 84]

# %% [markdown]
# ### 3. Thực hiện thống kê:
#
# - Tính tổng mảng
# - Tìm giá trị trung bình
# - Tìm giá trị trung vị
# - Tìm Q1, Q2, Q3
# - Tìm phân vị 20 (percentile 20)

# %%
# Tổng mảng
print(np.sum(arr))
# Out:
# 52873

# %%
# Giá trị trung bình
print(np.mean(arr))
# Out:
# 528.73

# %%
# Giá trị trung vị
print(np.median(arr))
# Out:
# 558.5

# %%
# Q1, Q2, Q3
print(np.percentile(arr, 25))
print(np.percentile(arr, 50))
print(np.percentile(arr, 75))
# Out:
# 311.75
# 558.5
# 769.75

# %%
# Phân vị 20 
print(np.percentile(arr, 20))
# Out:
# 240.4

# %% [markdown]
# ### 4. Thực hiện việc chọn ngẫu nhiên (không thay thế) 10 phần tử từ mảng trên 5 lần. Hiển thị kết quả lựa chọn mỗi lần

# %%
for i in range (10) :
    select_10 = np.random.choice(arr, 10)
    print(f"Lần chọn thứ {i + 1} : {select_10}")
# Out:
# Lần chọn thứ 1 : [501 539 827 747   5 385 573 447  93 179]
# Lần chọn thứ 2 : [119 615 691 940 884 384 630 730 994 857]
# Lần chọn thứ 3 : [409 569 350 501 302 956 370 368 913 630]
# Lần chọn thứ 4 : [940  94 301 501 573 485 684 312 956 119]
# Lần chọn thứ 5 : [573 765  84  94 859 827 311 639 884 121]
# Lần chọn thứ 6 : [884 359 815 374 940 130 569 691 799 301]
# Lần chọn thứ 7 : [747 350 587 531 500 747 486 359  81   5]
# Lần chọn thứ 8 : [639 857 784 747 730 812 384 730 913 573]
# Lần chọn thứ 9 : [984  93 684 799 603 385  81 918 798 179]
# Lần chọn thứ 10 : [531 651 569 594 639 884  84 799 374 960]

# %% [markdown]
# ### 5. Tìm phần tử xuất hiện nhiều nhất trong mảng

# %%
from collections import Counter
count = Counter(arr)
print("Phần tử xuất hiện nhiều nhất : ", count.most_common(1)[0][0])
# Out:
# Phần tử xuất hiện nhiều nhất :  747

# %% [markdown]
# ---

# %% [markdown]
# ## MATPLOTLIB

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# Viết mã để vẽ các đồ thị giống hình sau:

# %% [markdown]
# ### Câu 1: Đồ thị đường thẳng

# %%
# This cell contains output. Don't remove!

# %%
# YOUR CODE HERE

x = [1, 2, 3]
y = [2, 4, 1]

plt.plot(x, y)
plt.xlabel('x - axis')
plt.ylabel('y - axis')

plt.title('Sample graph!')
plt.xticks([1.00, 1.25, 1.50, 1.75, 2.00, 2.25, 2.50, 2.75, 3.00])
plt.yticks([1.0, 1.5, 2.0, 2.5, 3.0, 3.5, 4.0])
plt.show()

# %% [markdown]
# ### Câu 2: Vẽ hai đường thẳng

# %%
# This cell contains output. Don't remove!

# %%
# YOUR CODE HERE

x = [10, 20, 30]
y1 = [20, 40, 10]
y2 = [40, 10, 30]

plt.plot(x, y1, color = "red", label = "line 1")
plt.plot(x, y2, color = "blue", label = "line 2")
plt.xlabel('x - axis')
plt.ylabel('y - axis')
plt.title('Đồ thị hai đường thẳng')
plt.legend()
plt.show()

# %% [markdown]
# ### Câu 3: Sử dụng marker

# %%
# This cell contains output. Don't remove!

# %%
# YOUR CODE HERE

x = [1,4,5,6,7]
y = [2,6,3,6,3]

plt.plot(x, y, color = 'blue', marker = 'o', markerfacecolor = 'orange')
plt.xlabel('x - axis')
plt.ylabel('y - axis')
plt.title('Sử dụng marker')
plt.show()

# %% [markdown]
# ### Câu 4: Định dạng đường thẳng
#
# Phát sinh x là các điểm dữ liệu từ $[0, \pi]$. Bạn hãy vẽ đồ thị $y = sin(x)$ và $y = cos(x)$ như dưới đây.
# Gợi ý: sử dụng hằng số pi và hàm sau:
# - `np.pi` : số $\pi$
# - `np.linspace()`
# - `np.sin()`
# - `np.cos()`

# %%
# This cell contains output. Don't remove!

# %%
# YOUR CODE HERE
# y = sin(x)
pi = np.pi
x = np.linspace(0, 2 * pi, 100)

y1 = np.sin(x)
y2 = np.cos(x)

plt.plot(x, y1, label = 'sin(x)', color = 'blue')
plt.plot(x, y2, linestyle = '--' , label = 'cos(x)', color = 'red')
plt.grid()
plt.legend()
plt.show()

# %% [markdown]
# ### Câu 5: Vẽ các đồ thị con

# %%
# This cell contains output. Don't remove!

# %%
# YOUR CODE HERE
x = np.linspace(0, 2 * np.pi, 100)
y1 = np.sin(x)
y2 = np.cos(x)

plt.subplot(2, 1, 1)
plt.title("Đồ thị hàm sin(x) và cos(x)")
plt.plot(x, y1, label = 'sin(x)', color = 'blue')
plt.grid()
plt.legend()
plt.subplot(2, 1, 2)
plt.plot(x, y2, label = 'cos(x)', color = 'red')
plt.grid()
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Câu 6: Vẽ đồ thị cột

# %%
# This cell contains output. Don't remove!

# %%
# YOUR CODE HERE
programming_languages = ['Java', 'Python', 'PHP', 'JavaScript', 'C#', 'C++']
popularity = [22.2, 17.6, 8.8, 8, 7.7, 6.7]

plt.bar(programming_languages, popularity)
plt.xlabel('Programming languages')
plt.ylabel('Popularity')
plt.title("Mức độ phổ biến của các ngôn ngữ lập trình")
plt.show()

# %% [markdown]
# ### Câu  7: Vẽ đồ thị bánh

# %%
# This cell contains output. Don't remove!

# %%
# YOUR CODE HERE
programming_languages = ['Python', 'PHP', 'JavaScript', 'C#', 'C++', 'Java']
popularity = [17.6, 8.8, 8, 7.7, 6.7, 22.2]
plt.pie(popularity, labels = programming_languages, autopct = '%1.2f%%', colors = ['#F27405', '#3CB371', '#D2691E', '#911EB4', '#808080', '#1F77B4'])
plt.show()

# %% [markdown]
# ### Câu 8: Vẽ histogram
#
# Sử dụng hàm `np.random.normal(size=10000)` để phát sinh 10000 số ngẫu nghiên thuộc phân phối chuẩn. Vẽ histogram các số ngẫu nhiên trên.

# %%
# This cell contains output. Don't remove!

# %%
# YOUR CODE HERE
ar = np.random.normal(size=1000)
plt.hist(ar, bins = 100)
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title('Histogram')
plt.show()

# %% [markdown]
# ### Câu 9: Vẽ đồ thị hộp
#
# Sử dụng hàm `np.random.normal(size=10000)` để phát sinh 10000 số ngẫu nghiên thuộc phân phối chuẩn. Vẽ boxplot các số ngẫu nhiên trên.

# %%
# This cell contains output. Don't remove!

# %%
# YOUR CODE HERE
box = np.random.normal(size=1000)
plt.boxplot(box)
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title('Boxplot')
plt.show()

# %% [markdown]
# ### Câu 10: Kết hợp trên cùng một đồ thị
#
# Sử dụng hàm `np.random.normal(size=10000)` để phát sinh 10000 số ngẫu nghiên thuộc phân phối chuẩn. Vẽ hình thể hiện phân phối như sau:
#
# Hướng dẫn: thêm tham số `vert=False` trong hàm vẽ `boxplot()`

# %%
# This cell contains output. Don't remove!

# %%
ar = np.random.normal(size=1000)
plt.subplot(2, 1, 1)
plt.hist(ar, bins = 100, color='#0066FF', edgecolor='white')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title('Histogram')
plt.subplot(2, 1, 2)
plt.boxplot(ar, vert = False)
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title('Boxplot')
plt.tight_layout()
plt.show()

# %% [markdown]
# ---
